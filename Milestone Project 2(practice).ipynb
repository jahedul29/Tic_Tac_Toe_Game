# %% [markdown]
# ## Step 1
# definition of Card() class

# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two','Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'King', 'Queen', 'Jack', 'Ace')
values = {'Two':2,'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'King':10, 'Queen':10, 'Jack':10, 'Ace':11}

playing = True

class Card():
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        
    def __str__(self):
        return self.suit + ' : ' + self.rank

# %% [markdown]
# ### Step 2
# Defining Deck() class

# %%
class Deck():
    def __init__(self):
        self.deck = []
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit, rank))
    
    def __str__(self):
        deck_collection = ''
        for card in self.deck:
            deck_collection = deck_collection + str(card) +'\n\n'
        return deck_collection
    
    def shuffle(self):
        random.shuffle(self.deck)
    
    def deal(self):
        single_card = self.deck.pop()
        return single_card

# %% [markdown]
# #### Step 4
# Creating a Hand Class

# %%
class Hand():
    def __init__(self):
        self.card = []
        self.value = 0
        self.ace = 0
        self.real_value = 0
        
    def add_card(self, card):
        self.card.append(card)
        self.value += values[card.rank]
        self.real_value = self.value
        if card.rank == 'Ace':
            self.ace += 1
        
    def adjust_for_ace(self):
        while self.value > 21 and self.ace:
            self.value -=10
            self.ace -= 1

# %%
player1_hand = Hand()
deck = Deck()
deck.shuffle()
player1_hand.add_card(deck.deal())
player1_hand.add_card(deck.deal())
player1_hand.adjust_for_ace()
player1_hand.add_card(deck.deal())
player1_hand.adjust_for_ace()

# %%
for card in player1_hand.card:
    print(card)
print(player1_hand.value)
print(player1_hand.real_value)
try:
    player1_hand.card[0].rank
except:
    print("Error occured!!\n")
# Out:
# Hearts : Six
# Diamonds : Three
# Diamonds : Ace
# 20
# 20

# %% [markdown]
# #### Step 5
# Creating Chips class

# %%
class Chips():
    def __init__(self, total = 100):
        self.total = total
        self.bet_money = 0
        
    def win_bet(self):
        self.total += self.bet_money
        
    def lose_bet(self):
            self.total -= self.bet_money

# %% [markdown]
# ## Different Function definition

# %%
def take_bet(chips):
    while True:
        try:
            x = int(input("Enter bet amount : "))
        except:
            print("Enter a valid integer")
        else:
            if x > chips.total:
                print("Not Enough Balance\n\n")
            else:
                chips.bet_money = x
                break

# %%
def hit(deck, hand):
    hand.add_card(deck.deal())
    hand.adjust_for_ace()

# %%
def hit_or_stand(deck, hand):
    global playing
    while True:
        decision = input("Hit or Stand? Enter 'h' or 's' : ")
        print(decision)
        if decision.lower() == 'h':
            hit(deck,hand)
            break
        elif decision.lower() == 's':
            print("\nPlayer Stands!! It's dealers turn\n\n")
            playing = False
            break
        else:
            print("Enter only 'h' or 's'")

# %%
def player_busts(chips):
    print("\nPlayer busts\n\nDealer wins\n\n")
    chips.lose_bet()
    
def player_wins(chips):
    print("\nPlayer Wins\n\n")
    chips.win_bet()
    
def dealer_busts(chips):
    print("\nDealer busts\n\nPlayer Wins\n\n")
    chips.win_bet()
    
def dealer_wins(chips):
    print("\nDealer wins\n\n")
    chips.lose_bet()
    
def push():
    print("\nPush!! No one wins!\n\n")

# %%
def show_some(player, dealer):
    print("DEALER'S HAND : \n")
    print("One card hidden!!\n")
    print(dealer.card[1])
    print("Total value of Dealer: {}\n\n".format(values[dealer.card[1].rank]))
    print("\n")
    
    print("PLAYER'S HAND :\n")
    for card in player.card:
        print(card)
    print("Total value of Player: {}\n\n".format(player.value))
    
def show_all(player, dealer):
    print("DEALER'S HANE : \n")
    for card in dealer.card:
        print(card)
    print("Total value : {}\n\n".format(dealer.value))    
    print("\n")
    
    print("PLAYER'S HAND :\n")
    for card in player.card:
        print(card)
    print("Total value : {}\n\n".format(player.value))

# %%
def replay():
    
    decision = input('Do you want to replay the gamy ?? Y or N?')
    while decision.lower() != 'y' and decision.lower() != 'n' :
        print('Enter valid input !!\n')
        decision = input('Do you want to replay the gamy ?? Y or N? : ')
        
    if decision.lower() == 'y':
        return True
    else:
        return False

# %% [markdown]
# ## Final Step

# %%
while True:
    ### Welcome Note
    print("..........Welcome to BlackJack...........\n\n")
    
    #importing random module
    import random

    #Global variables for creating deck
    suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
    ranks = ('Two','Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'King', 'Queen', 'Jack', 'Ace')
    values = {'Two':2,'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'King':10, 'Queen':10, 'Jack':10, 'Ace':11}

    #Global variable for controlling gameplay
    playing = True
    is_player_busts = False
    
    
    #Creating a deck of 52 cards
    deck = Deck()
    deck.shuffle()
    
    #Creating player and dealer hand
    player_hand = Hand()
    dealer_hand = Hand()
    
    #Creating player's chips
    player_chips = Chips(100)
    
    #Placing a Bet
    take_bet(player_chips)
    
    #Giving two cards to player and dealer
    for i in range(2):
        player_hand.add_card(deck.deal())
        dealer_hand.add_card(deck.deal())
    
    #Adjust ace for both
    player_hand.adjust_for_ace()
    dealer_hand.adjust_for_ace()
    
    #Showing all cards except dealers second card
    show_some(player_hand, dealer_hand)
    
    #Finding Blackjack
    if player_hand.value == 21:
        print("\nBlackJack!!!\n")
        player_wins(player_chips)
        print(f"Player's total chips : {player_chips.total}")
        if replay():
            continue
        print("\n\n.............Thank You...........\n")
        break
    
    while playing:
        #Asking player To Hit or Stand
        hit_or_stand(deck, player_hand)
        
        #Adjusting card display
        if playing:
            show_some(player_hand, dealer_hand)
        else:
            show_all(player_hand, dealer_hand)
        
        #Checking if the player busts or not
        if player_hand.value > 21:
            player_busts(player_chips)
            print(f"Player's total chips : {player_chips.total}")
            is_player_busts = True
            break
    
    #Conditon for replay after bust
    if is_player_busts:
        if replay():
            continue
        else:
            print("\n\n.............Thank You...........\n")
            break
    
    #If player stands or Not bust
    if player_hand.value < 21:
        #Deal cards to the dealer until it exeeds player's value
        while dealer_hand.value < player_hand.value:
            hit(deck,dealer_hand)
        
        #Showing all cards
        show_all(player_hand,dealer_hand)
        
        #Different winning scenario
        if dealer_hand.value > 21:
            dealer_busts(player_chips)
        elif dealer_hand.value < player_hand.value:
            player_wins(player_chips)
        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_chips)
        else:
            push()
            
    print(f"Player's total chips : {player_chips.total}")    
    if replay():
        continue
    else:
        print("\n\n.............Thank You...........\n")
        break
# Out:
# ..........Welcome to BlackJack...........
#
#
# Enter bet amount : 30
# DEALER'S HAND :
#
# One card hidden!!
#
# Hearts : King
# Total value of Dealer: 10
#
#
#
#
# PLAYER'S HAND :
#
# Diamonds : Ace
# Clubs : Four
# Total value of Player: 15
#
#
# Hit or Stand? Enter 'h' or 's' : h
# h
# DEALER'S HAND :
#
# One card hidden!!
#
# Hearts : King
# Total value of Dealer: 10
#
#
#
#
# PLAYER'S HAND :
#
# Diamonds : Ace
# Clubs : Four
# Clubs : Three
# Total value of Player: 18
#
#
# Hit or Stand? Enter 'h' or 's' : s
# s
#
# Player Stands!! It's dealers turn
#
#
# DEALER'S HANE :
#
# Clubs : Seven
# Hearts : King
# Total value : 17
#
#
#
#
# PLAYER'S HAND :
#
# Diamonds : Ace
# Clubs : Four
# Clubs : Three
# Total value : 18
#
#
# DEALER'S HANE :
#
# Clubs : Seven
# Hearts : King
# Spades : Jack
# Total value : 27
#
#
#
#
# PLAYER'S HAND :
#
# Diamonds : Ace
# Clubs : Four
# Clubs : Three
# Total value : 18
#
#
#
# Dealer busts
#
# Player Wins
#
#
# Player's total chips : 130
# ...
